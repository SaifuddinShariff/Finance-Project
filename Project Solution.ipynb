# %%
import pandas as pd

df = pd.read_csv('Finance.csv')

df
# Out:
#        Product   Discount Band   Units Sold   Manufacturing Price   \
# 0    Carretera            None       1618.5                    3.0
# 1    Carretera            None       1321.0                    3.0
# 2    Carretera            None       2178.0                    3.0
# 3    Carretera            None        888.0                    3.0
# 4    Carretera            None       2470.0                    3.0
# 5    Carretera            None       1513.0                    3.0
# 6      Montana            None        921.0                    5.0
# 7      Montana            None       2518.0                    5.0
# 8      Montana            None       1899.0                    5.0
# 9      Montana            None       1545.0                    5.0
# 10     Montana            None       2470.0                    5.0
# 11     Montana            None       2665.5                    5.0
# 12     Montana            None        958.0                    5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0    Product               38 non-null     object
#  1    Discount Band         38 non-null     object
#  2   Units Sold             38 non-null     float64
#  3    Manufacturing Price   38 non-null     float64
#  4    Sale Price            38 non-null     float64
#  5    Gross Sales           38 non-null     float64
#  6    COGS                  38 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#         Units Sold   Manufacturing Price    Sale Price    Gross Sales   \
# count    38.000000              38.000000     38.000000      38.000000
# mean   1483.078947              27.842105     87.815789  116872.223684
# std     742.745296              44.462876    125.529980  172261.914853
# min     292.000000               3.000000      7.000000    4404.000000
# 25%     914.250000               5.000000     12.000000   14013.750000
# 50%    1513.000000              10.000000     15.000000   32325.000000
# 75%    2150.500000              10.000000    125.000000  179906.250000
# max    2821.000000             120.000000    350.000000  603750.000000
#
#                COGS
# count      38.000000
# mean    90577.052632
# std    137913.434900
# min      1101.000000
# 25%      6728.500000
# 50%     17177.500000
# 75%    158100.000000
# max    448500.000000

# %%
df.head()
# Out:
#       Product   Discount Band   Units Sold   Manufacturing Price   \
# 0   Carretera            None       1618.5                    3.0
# 1   Carretera            None       1321.0                    3.0
# 2   Carretera            None       2178.0                    3.0
# 3   Carretera            None        888.0                    3.0
# 4   Carretera            None       2470.0                    3.0
#
#     Sale Price    Gross Sales     COGS
# 0          20.0        32370.0  16185.0
# 1          20.0        26420.0  13210.0
# 2          15.0        32670.0  21780.0
# 3          15.0        13320.0   8880.0
# 4          15.0        37050.0  24700.0

# %%
df.tail()
# Out:
#     Product   Discount Band   Units Sold   Manufacturing Price    Sale Price   \
# 33     Velo            None       2161.0                  120.0          12.0
# 34     Velo            None       1006.0                  120.0         350.0
# 35     Velo            None       1545.0                  120.0          12.0
# 36     Velo            None       2821.0                  120.0         125.0
# 37     Velo            None        345.0                  120.0         125.0
#
#      Gross Sales      COGS
# 33        25932.0    6483.0
# 34       352100.0  261560.0
# 35        18540.0    4635.0
# 36       352625.0  338520.0
# 37        43125.0   41400.0

# %%
df.shape
# Out:
# (38, 7)

# %%
df.columns
# Out:
# Index([' Product ', ' Discount Band ', 'Units Sold', ' Manufacturing Price ',
#        ' Sale Price ', ' Gross Sales ', ' COGS '],
#       dtype='object')

# %%
pd.isnull(df)
# Out:
#      Product    Discount Band   Units Sold   Manufacturing Price   \
# 0       False            False       False                  False
# 1       False            False       False                  False
# 2       False            False       False                  False
# 3       False            False       False                  False
# 4       False            False       False                  False
# 5       False            False       False                  False
# 6       False            False       False                  False
# 7       False            False       False                  False
# 8       False            False       False                  False
# 9       False            False       False                  False
# 10      False            False       False                  False
# 11      False            False       False                  False
# 12      False            False       False                  False
# ...

# %%
pd.notnull(df)
# Out:
#      Product    Discount Band   Units Sold   Manufacturing Price   \
# 0        True             True        True                   True
# 1        True             True        True                   True
# 2        True             True        True                   True
# 3        True             True        True                   True
# 4        True             True        True                   True
# 5        True             True        True                   True
# 6        True             True        True                   True
# 7        True             True        True                   True
# 8        True             True        True                   True
# 9        True             True        True                   True
# 10       True             True        True                   True
# 11       True             True        True                   True
# 12       True             True        True                   True
# ...

# %%
df.drop(' Discount Band ', axis=1, inplace=True)

# %%
df
# Out:
#        Product   Units Sold   Manufacturing Price    Sale Price   \
# 0    Carretera       1618.5                    3.0          20.0
# 1    Carretera       1321.0                    3.0          20.0
# 2    Carretera       2178.0                    3.0          15.0
# 3    Carretera        888.0                    3.0          15.0
# 4    Carretera       2470.0                    3.0          15.0
# 5    Carretera       1513.0                    3.0         350.0
# 6      Montana        921.0                    5.0          15.0
# 7      Montana       2518.0                    5.0          12.0
# 8      Montana       1899.0                    5.0          20.0
# 9      Montana       1545.0                    5.0          12.0
# 10     Montana       2470.0                    5.0          15.0
# 11     Montana       2665.5                    5.0         125.0
# 12     Montana        958.0                    5.0         300.0
# ...

# %%
df.dtypes
# Out:
#  Product                  object
# Units Sold               float64
#  Manufacturing Price     float64
#  Sale Price              float64
#  Gross Sales             float64
#  COGS                    float64
# dtype: object

# %%
df['Units Sold'].dtypes
# Out:
# dtype('float64')

# %%
df[' Sale Price '].dtypes
# Out:
# dtype('float64')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_gross = df[ (df[' Gross Sales ']) <20000].index

df.drop(df_gross, inplace=True)

df
# Out:
#        Product   Units Sold   Manufacturing Price    Sale Price   \
# 0    Carretera       1618.5                    3.0          20.0
# 1    Carretera       1321.0                    3.0          20.0
# 2    Carretera       2178.0                    3.0          15.0
# 4    Carretera       2470.0                    3.0          15.0
# 5    Carretera       1513.0                    3.0         350.0
# 7      Montana       2518.0                    5.0          12.0
# 8      Montana       1899.0                    5.0          20.0
# 10     Montana       2470.0                    5.0          15.0
# 11     Montana       2665.5                    5.0         125.0
# 12     Montana        958.0                    5.0         300.0
# 14     Montana        345.0                    5.0         125.0
# 18       Paseo       2518.0                   10.0          12.0
# 19       Paseo       1006.0                   10.0         350.0
# ...

# %%
df.to_csv('Solution.csv')
